# %%
# !pip install -q transformers sentence-transformers razdel

# %% [markdown]
# # Генерация train_backtranslate.csv

# %%
import os
import sys
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
drive_root = '/content/drive/MyDrive/papadyk-collab/vkr'
output_dir = os.path.join(drive_root, 'output')
os.makedirs(output_dir, exist_ok=True)

TRAIN_FILE = os.path.join(drive_root, 'train.csv')
OUT_DIR = os.path.join(output_dir, 'backtranslate-4')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(HF_TOKEN)

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
repo = "sevaTechoPark/mifi-vkr"
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{repo}.git

import sys
sys.path.insert(0, "/content/mifi-vkr")
# Out:
# Cloning into 'mifi-vkr'...
# remote: Enumerating objects: 638, done.
# remote: Counting objects: 100% (435/435), done.
# remote: Compressing objects: 100% (283/283), done.
# remote: Total 638 (delta 265), reused 307 (delta 151), pack-reused 203 (from 3)
# Receiving objects: 100% (638/638), 148.06 MiB | 33.77 MiB/s, done.
# Resolving deltas: 100% (338/338), done.

# %%
from augmentation.backtranslate.main import run_from_params as run_backtranslate

df_full_bt, df_aug_bt = run_backtranslate(
    train_file=TRAIN_FILE,
    output_dir=OUT_DIR,
    seed=42,
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/359 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/596M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/134 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/551M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/149 [00:00<?, ?it/s]
# ...
