# %%
# !pip install -q transformers sentence-transformers razdel

# %% [markdown]
# # Генерация train_augmentation.csv

# %%
import os
import sys
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
drive_root = '/content/drive/MyDrive/papadyk-collab/vkr'
output_dir = os.path.join(drive_root, 'output')
os.makedirs(output_dir, exist_ok=True)

TRAIN_FILE = os.path.join(drive_root, 'train.csv')
OUT_DIR = os.path.join(output_dir, 'paraphrase-4')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(HF_TOKEN)

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
repo = "sevaTechoPark/mifi-vkr"
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{repo}.git

import sys
sys.path.insert(0, "/content/mifi-vkr")
# Out:
# Cloning into 'mifi-vkr'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (443/443), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 646 (delta 272), reused 311 (delta 154), pack-reused 203 (from 3)
# Receiving objects: 100% (646/646), 148.06 MiB | 32.87 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
from augmentation.paraphrase.main import run_from_params as run_paraphrase

df_full, df_aug = run_paraphrase(
    train_file=TRAIN_FILE,
    output_dir=OUT_DIR,
    seed=42,
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/359 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/596M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/134 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/509 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# Всего малых классов: 23
# Текущее количество примеров в малых классах: 264
# Целевое количество на класс: 30
# Нужно сгенерировать аугментаций: 426
# Загружено уже сгенерированных примеров: 20
# Labels:   0%|          | 0/23 [00:00<?, ?it/s]
# Label: Имущественные вопросы | есть 5, нужно добить: 25
# W0513 21:19:25.903000 20252 torch/_inductor/utils.py:1679] [1/0_1] Not enough SMs to use max_autotune_gemm mode
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# Добавлено 1/406 аугментаций
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# Добавлено 2/406 аугментаций
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# Добавлено 3/406 аугментаций
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
# [SKIP] sim с лейблом=1.0000
# Sentences:   0%|          | 0/2 [00:00<?, ?it/s]
