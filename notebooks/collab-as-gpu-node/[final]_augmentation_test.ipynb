# %%
# !pip install -q transformers sentence-transformers razdel

# %% [markdown]
# # Генерация train_augmentation.csv

# %%
import os
import sys
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
drive_root = '/content/drive/MyDrive/papadyk-collab/vkr'
output_dir = os.path.join(drive_root, 'output')
os.makedirs(output_dir, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(HF_TOKEN)

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
repo = "sevaTechoPark/mifi-vkr"
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{repo}.git

import sys
sys.path.insert(0, "/content/mifi-vkr")
# Out:
# Cloning into 'mifi-vkr'...
# remote: Enumerating objects: 570, done.
# remote: Counting objects: 100% (367/367), done.
# remote: Compressing objects: 100% (235/235), done.
# remote: Total 570 (delta 216), reused 270 (delta 131), pack-reused 203 (from 3)
# Receiving objects: 100% (570/570), 146.02 MiB | 11.90 MiB/s, done.
# Resolving deltas: 100% (289/289), done.

# %%
import os
import torch
from augmentation.common.embeddings import load_embed_model, cos_sim
from augmentation.common.perplexity import load_rugpt

from augmentation.paraphrase.models import load_paraphrase_model
from augmentation.paraphrase.augment import paraphrase_document
from augmentation.backtranslate.augment import back_translate_document

embed_model             = load_embed_model(device)
tok, para_model         = load_paraphrase_model(device)
rugpt_tok, rugpt_model  = load_rugpt(device)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/359 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/596M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/134 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/509 [00:00<?, ?it/s]
# ...

# %%
paraphrase_document(
    source_text="тест запуска",
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
# Out:
# Sentences:   0%|          | 0/1 [00:00<?, ?it/s]
# W0513 17:34:24.494000 3640 torch/_inductor/utils.py:1679] [1/0_1] Not enough SMs to use max_autotune_gemm mode
# 'Запуск прошел успешно.'

# %%
back_translate_document(
    text_orig="тест запуска",
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
# Out:
# Sentences:   0%|          | 0/1 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/307M [00:00<?, ?B/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %%
source_text = "[ORGANIZATION] Почтовый/Юридический адрес: [LOCATION] Телефон: [CONTACT]; [CONTACT], факс: [CONTACT] e-mail: [CONTACT] ОКПО [ID], ОГРН [ID], ИНН/КПП [ID]/[ID] от [DATE_TIME] No [DOCUMENT_NUMBER] [DOCUMENT_NUMBER] [DATE_TIME] г. на No от Руководителю проекта [OBJECT] [PERSON] [CONTACT] О проезде техники через КПП [OBJECT] Уважаемый [PERSON]! На письмо исх. No [DOCUMENT_NUMBER] от [DATE_TIME] сообщаем Вам, что [ORGANIZATION] не согласовывает проезд транспорта [ORGANIZATION] через ДКП-1 с проездом по территории [OBJECT] и выездом через ДКП-2 ([NUMBER] км) к трассе трубопровода [ORGANIZATION]. Рекомендуем Вам рассмотреть проезд по вдольтрассовому проезду (ВТП) [ORGANIZATION] с заездом через ДКП-3 ([NUMBER] км), а/т должен быть оснащен искрогасителями, также персонал иметь при себе подтверждающий документ о прохождении инструктажа по требованиям пожарной безопасности. В случае Вашего согласия просим подтвердить официальным письмом. Обращаем Ваше внимание, что в мае-июне на ВТП [ORGANIZATION] будут действовать сезонные ограничения по проезду техники, связанные с паводковым периодом в [LOCATION], просим Вас заблаговременно уточнять в [ORGANIZATION] о возможности проезда по ВТП. Для оформления пропусков просим Вас направить [PERSON], [PERSON], наименование перевозимого груза с привязкой к автомобильному транспорту в форме заявки (приложение), а также лист ознакомления со Стандартом [ORGANIZATION] пропускной и внутритобъектовый режимы на территории производственных и иных объектов No [DOCUMENT_NUMBER]. Приложение: Образец заявки на проезд – на 1 л. в 1 экз. Первый заместитель генерального директора по производству – главный инженер [PERSON] [PERSON] [CONTACT], доб. [NUMBER] [CONTACT] ДОКУМЕНТ ПОДЛИННАЯ ЭЛЕКТРОННОЙ ПОДЛИННОСТИ Сертификат [FINANCIAL_DATA] [FINANCIAL_DATA] Владелец [PERSON] Действителен с [DATE_TIME] по [DATE_TIME]"

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/11 [00:00<?, ?it/s]
# === Source ===
# ...

# %%
source_text = """
[ORGANIZATION]
Юридический адрес: [LOCATION]
Телефон: [CONTACT], e-mail: [CONTACT]

Исх. No [DOCUMENT_NUMBER] от [DATE_TIME]

Руководителю проекта [OBJECT]
[PERSON]
О согласовании въезда автотранспорта

Уважаемый [PERSON]!

В рамках договора No [DOCUMENT_NUMBER] от [DATE_TIME] просим согласовать въезд
автотранспорта [ORGANIZATION] через КПП [OBJECT] для выполнения работ по
обслуживанию объектов [OBJECT].

Автотранспорт должен быть оснащен исправными искрогасителями, а водители и
сопровождающий персонал – пройти инструктаж по требованиям пожарной безопасности,
о чём иметь при себе подтверждающие документы.

В случае согласия просим направить официальное письмо-подтверждение
в адрес [ORGANIZATION] по контактам, указанным в шапке.

С уважением,
[PERSON]
должность: [ID]
тел.: [CONTACT]
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/6 [00:00<?, ?it/s]
# === Source ===
#
# [ORGANIZATION]
# Юридический адрес: [LOCATION]
# Телефон: [CONTACT], e-mail: [CONTACT]
#
# Исх. No [DOCUMENT_NUMBER] от [DATE_TIME]
#
# Руководителю проекта [OBJECT]
# [PERSON]
# О согласовании въезда автотранспорта
#
# Уважаемый [PERSON]!
#
# В рамках договора No [DOCUMENT_NUMBER] от [DATE_TIME] просим согласовать въезд
# автотранспорта [ORGANIZATION] через КПП [OBJECT] для выполнения работ по
# обслуживанию объектов [OBJECT].
#
# Автотранспорт должен быть оснащен исправными искрогасителями, а водители и
# сопровождающий персонал – пройти инструктаж по требованиям пожарной безопасности,
# о чём иметь при себе подтверждающие документы.
#
# В случае согласия просим направить официальное письмо-подтверждение
# в адрес [ORGANIZATION] по контактам, указанным в шапке.
#
# С уважением,
# [PERSON]
# должность: [ID]
# тел.: [CONTACT]
#
#
# === Paraphrased ===
# ...

# %%
source_text = """
[ORGANIZATION]
Почтовый адрес: [LOCATION]
Телефон: [CONTACT], факс: [CONTACT], e-mail: [CONTACT]

Исх. No [DOCUMENT_NUMBER] от [DATE_TIME]

Руководителю службы безопасности [ORGANIZATION]
[PERSON]

О продлении срока действия пропусков

Уважаемый [PERSON]!

В соответствии с договором No [DOCUMENT_NUMBER] от [DATE_TIME] на выполнение
работ по обустройству объектов [OBJECT] просим продлить срок действия
временных пропусков на территорию [OBJECT] для следующих сотрудников
[ORGANIZATION]:

1) [PERSON], табельный No [ID];
2) [PERSON], табельный No [ID];
3) [PERSON], табельный No [ID].

Срок продления пропусков – с [DATE_TIME] по [DATE_TIME] включительно.

Обращаем внимание, что доступ к объектам [OBJECT] осуществляется исключительно
через КПП [LOCATION] при наличии действующих пропусков и документов,
удостоверяющих личность.

Приложение: список сотрудников с паспортными данными и номерами автотранспорта –
на [NUMBER] л. в [NUMBER] экз.

С уважением,
[PERSON]
должность: [ID]
контактный телефон: [CONTACT]
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/9 [00:00<?, ?it/s]
# === Source ===
#
# [ORGANIZATION]
# Почтовый адрес: [LOCATION]
# Телефон: [CONTACT], факс: [CONTACT], e-mail: [CONTACT]
#
# Исх. No [DOCUMENT_NUMBER] от [DATE_TIME]
#
# Руководителю службы безопасности [ORGANIZATION]
# [PERSON]
#
# О продлении срока действия пропусков
#
# Уважаемый [PERSON]!
#
# В соответствии с договором No [DOCUMENT_NUMBER] от [DATE_TIME] на выполнение
# работ по обустройству объектов [OBJECT] просим продлить срок действия
# временных пропусков на территорию [OBJECT] для следующих сотрудников
# [ORGANIZATION]:
#
# 1) [PERSON], табельный No [ID];
# 2) [PERSON], табельный No [ID];
# 3) [PERSON], табельный No [ID].
#
# Срок продления пропусков – с [DATE_TIME] по [DATE_TIME] включительно.
#
# Обращаем внимание, что доступ к объектам [OBJECT] осуществляется исключительно
# через КПП [LOCATION] при наличии действующих пропусков и документов,
# удостоверяющих личность.
#
# ...

# %%
source_text = """
[ORGANIZATION] Юридический адрес: [LOCATION] Почтовый адрес: [LOCATION] тел., факс: [CONTACT] приемная тел.: [CONTACT] бухгалтерия тел.: [CONTACT] ПТО тел.: [CONTACT] e-mail to: [CONTACT] ОГРН [ID] ОКТМО [ID] ОКВЭД [ID] ИНН [ID] КПП [ID] БИК [ID] р/с [FINANCIAL_DATA] к/с [FINANCIAL_DATA] [ORGANIZATION] ПАО [ORGANIZATION] Исх.No [DOCUMENT_NUMBER] [DATE_TIME] Руководителю проекта [ORGANIZATION] [PERSON] О смене пропуска Уважаемый [PERSON]! В рамках Договора No [DOCUMENT_NUMBER] от [DATE_TIME] на выполнение комплекса работ по обустройству газовых и нефтяных кустов, площадочных объектов [OBJECT], [OBJECT], [OBJECT] месторождений сообщаем, что в мае месяце у [ORGANIZATION] закончились договоры лизинга на транспортные средства в количестве 17 единиц. В связи с этим, были изменены регистрационные данные. Данные изменения влекут за собой необходимость смены пропусков [ORGANIZATION]. Процедура изменения наименования собственника в пропуске, подразумевает удаление транспортного средства и создание нового, с внесенными изменениями, в системе а.i-propusk. Что влечет за собой удаление действующих пропусков [ORGANIZATION]. На основании вышеизложенного, прошу Вас согласовать нахождение транспортных средств на объекте [OBJECT] [OBJECT] на период внесения изменения данных в системе а.i-propusk и замены пропусков. Приложение: 1. Перечень транспортных средств - 1л. [ORGANIZATION] Дата окончания поиска. [PERSON] Импректор [PERSON]
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/11 [00:00<?, ?it/s]
# === Source ===
#
# ...

# %%
source_text = """
[ORGANIZATION] [ID]; [ID]; [LOCATION] Телефон: [CONTACT] Эл. почта: [CONTACT]; www.[ORGANIZATION] Исх.No [DOCUMENT_NUMBER] от [DATE_TIME] Технический директор [ORGANIZATION] [PERSON] , [LOCATION] Совещание главных метрологов в [LOCATION] Уважаемый [PERSON]! С [DATE_TIME] по [DATE_TIME] в [LOCATION] состоится Семинар-совещание главных метрологов и ведущих специалистов в [REGION] и [REGION]. В 2023 году [ORGANIZATION] была удостоена Премией Правительства РФ в области качества, как разработчик и производитель КИПиА. Сервисные лаборатории аккредитованы на проведение калибровки, поверки и ремонта СИ. За 25 лет истории компания закрепила за собой звание производителя газоаналитического оборудования в мире, выпуская в среднем [FINANCIAL_DATA] приборов в год и поставляется в более [FINANCIAL_DATA] стран по всему миру. Приглашаем Вас и ваших коллег посетить наш стенд, в рамках вышеуказанного мероприятия, наглядно увидеть уникальные решения [ORGANIZATION], а именно: * Стационарные газоанализаторы ДГС Серии 200; * Стационарные газоанализаторы Серии Advant; * Портативные газоанализаторы ПГ-ЭРИС Серии 400; * Переносной взрывозащищенный комплекс ранней автоматизации Lora Ex; * Станция автоматической калибровки переносных газоанализаторов. Подробную информацию можно получить на сайте [LOCATION]. Надеемся на Вашу заинтересованность в развитии деловых отношений между нашими организациями и посещении Семинара. Коммерческий директор [ORGANIZATION] Исполнитель: [PERSON] [CONTACT] Тел. [CONTACT]"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/15 [00:00<?, ?it/s]
# === Source ===
#
# ...

# %%
source_text = """
В соответствии с договором поставки от 15 марта 2025 года просим согласовать перенос сроков отгрузки оборудования на одну неделю в связи с задержкой на таможне.
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/1 [00:00<?, ?it/s]
# === Source ===
#
# В соответствии с договором поставки от 15 марта 2025 года просим согласовать перенос сроков отгрузки оборудования на одну неделю в связи с задержкой на таможне.
#
#
# === Paraphrased ===
# В соответствии с контрактом на поставку оборудования от года просим согласовывать перенос сроков поставки оборудования на один день в связи с задержками на таможенном посту.
#
# Cosine similarity: 0.8701
#
# === Back-translated ===
# В соответствии с контрактом на поставку от 15 марта года мы просим договориться об отсрочке поставки оборудования на одну неделю из-за задержек с таможенной очисткой.
#
# Cosine similarity: 0.8378

# %%
source_text = """
В течение последних трёх лет наша компания реализует проект модернизации системы промышленной безопасности на объектах нефтегазовой отрасли. В рамках данного проекта были внедрены новые программно‑аппаратные комплексы мониторинга, проведено обучение персонала и разработаны регламенты реагирования на нештатные ситуации. По предварительным оценкам, это позволило снизить количество аварийных инцидентов более чем на тридцать процентов и сократить время простоя оборудования. Просим рассмотреть возможность расширения сотрудничества и включения дополнительных площадок в программу модернизации.
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/4 [00:00<?, ?it/s]
# === Source ===
#
# В течение последних трёх лет наша компания реализует проект модернизации системы промышленной безопасности на объектах нефтегазовой отрасли. В рамках данного проекта были внедрены новые программно‑аппаратные комплексы мониторинга, проведено обучение персонала и разработаны регламенты реагирования на нештатные ситуации. По предварительным оценкам, это позволило снизить количество аварийных инцидентов более чем на тридцать процентов и сократить время простоя оборудования. Просим рассмотреть возможность расширения сотрудничества и включения дополнительных площадок в программу модернизации.
#
#
# === Paraphrased ===
# ...

# %%
source_text = """
[ORGANIZATION]: [ID] КПП [ID], ОГРН [ID] [LOCATION], [OBJECT] [DOCUMENT_NUMBER] Иск. от [DATE_TIME] No [DOCUMENT_NUMBER] Руководителю по сопровождению договоров [ORGANIZATION] [PERSON] Уважаемая [PERSON]! На вышеуказанном рассмотрении проекта дополнительного соглашения к договору аренды земельных участков No [DOCUMENT_NUMBER] от [DATE_TIME], сообщаю о готовности подписать дополнительное соглашение в приложенной редакции. С уважением, Генеральный директор [ORGANIZATION] [PERSON]
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/3 [00:00<?, ?it/s]
# === Source ===
#
# [ORGANIZATION]: [ID] КПП [ID], ОГРН [ID] [LOCATION], [OBJECT] [DOCUMENT_NUMBER] Иск. от [DATE_TIME] No [DOCUMENT_NUMBER] Руководителю по сопровождению договоров [ORGANIZATION] [PERSON] Уважаемая [PERSON]! На вышеуказанном рассмотрении проекта дополнительного соглашения к договору аренды земельных участков No [DOCUMENT_NUMBER] от [DATE_TIME], сообщаю о готовности подписать дополнительное соглашение в приложенной редакции. С уважением, Генеральный директор [ORGANIZATION] [PERSON]
#
#
# === Paraphrased ===
# " o ref="true" и o ref="true" cliff o ref="true" inclusive.site " o ref="true. В соответствии с п. 12 проекта дополнительного соглашения о договоре аренды земельных участков от, сообщаю об их готовности подписать дополнительно. Щ
#
# Cosine similarity: 0.7956
#
# === Back-translated ===
# ...

# %%
source_text = """
[ORGANIZATION] ПРИКАЗ [DATE_TIME] No [DOCUMENT_NUMBER] Об утверждении Положений по непрофильным активам и порядке отчуждения непрофильных активов В целях приведения локальных нормативных актов Группы [ORGANIZATION] по вопросам управления непрофильными активами в соответствии с нормативными актами [ORGANIZATION] ПРИКАЗЫВАЮ: 1. Утвердить Положение о Комиссии по непрофильным активам [ORGANIZATION] и организаций Группы компаний [ORGANIZATION] в новой редакции (Приложение 1). 2. Утвердить Положение о порядке отчуждения непрофильных активов [ORGANIZATION] и организаций Группы компаний [ORGANIZATION] в новой редакции (Приложение 2). 3. Утвердить состав Комиссии по непрофильным активам [ORGANIZATION] в новом составе (Приложение 3). 4. Признать утратившими силу приказы [ORGANIZATION] от [DATE_TIME] No [DOCUMENT_NUMBER] и от [DATE_TIME] No [DOCUMENT_NUMBER]. 5. Распространить действие настоящего Приказа на организации Группы компаний [ORGANIZATION], в которых Компания имеет право прямо или косвенно распоряжаться более 50 голосов (Приложение 4). 6. Контроль исполнения приказа возложить на заместителя Председателя Правления [PERSON] Председатель Правления [PERSON] Приложение 1 к приказу [ORGANIZATION] от [DATE_TIME] No [DOCUMENT_NUMBER] ПОЛОЖЕНИЕ О КОМИССИИ [ORGANIZATION] И ОРГАНИЗАЦИЙ ГРУППЫ КОМПАНИЙ [ORGANIZATION] ПО НЕПРОФИЛЬНЫМ АКТИВАМ 1. Общие положения Настоящее Положение определяет цели, задачи, организацию деятельности Комиссии [ORGANIZATION] по непрофильным активам (далее – Комиссия), права и обязанности Председателя, Секретаря и членов Комиссии, а также порядок представления отчетов о ходе ее работы. Требования настоящего Положения обязательны для применения при отчуждении непрофильных активов [ORGANIZATION] и организаций Группы компаний [ORGANIZATION]. Дочерние общества и организации [ORGANIZATION] обеспечивают утверждение локальных нормативных актов (положений), регламентирующих в соответствии с настоящим Положением порядок работы комиссий по непрофильным активам в дочерних обществах, а также в объектах вложений дочерних обществ, являющихся организациями Группы компаний [ORGANIZATION]. Представители интересов [ORGANIZATION] и дочерних обществ [ORGANIZATION] в органах управления организаций Группы компаний [ORGANIZATION] обеспечивают на основе настоящего Положения утверждение локальных нормативных актов (положений), регламентирующих порядок работы комиссий по непрофильным активам в таких организациях Группы компаний [ORGANIZATION]. 2. Основные цели и задачи Комиссии 2.1. Комиссия создается в целях обеспечения реализации Стратегии по управлению им
# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# ...
# Sentences:   0%|          | 0/46 [00:00<?, ?it/s]
# === Source ===
#
# ...

# %%
source_text = """
[ORGANIZATION] ИНВЕСТ Общество с ограниченной ответственностью [ORGANIZATION] ИНВЕСТ (ООО [ORGANIZATION] ИНВЕСТ) Филиал [OBJECT] Заместителю генерального директора по производству [ORGANIZATION] Добыча [PERSON] С.П. [PERSON] Исполнительному директору [ORGANIZATION] Газпромнефть-Заполярье [PERSON] Сергеевич Уважаемый [PERSON] Петрович! Уважаемый [PERSON] Сергеевич! По объекту [OBJECT] Обустройство [OBJECT] Ямбургского НГКМ (код ПИР [DOCUMENT_NUMBER]) направляем письмо [ORGANIZATION] проектирование от [DATE_TIME] No [DOCUMENT_NUMBER] по согласованию возможности размещения автодороги [ORGANIZATION] Газпромнефть-Заполярье с [OBJECT] Песцового НГКМ до [OBJECT] Ямбургского НГКМ. Просим Вас поручить ответственным специалистам рассмотреть предложение [ORGANIZATION] проектирование о возможности согласования варианта отмыкания трассы автодороги к кусту No [DOCUMENT_NUMBER] и направить в адрес [PERSON] результаты рассмотрения и согласования. Приложение: 1. Письмо [ORGANIZATION] проектирование от [DATE_TIME] No [DOCUMENT_NUMBER] на 1 л. 2. Ситуационный план на 1 л. Временно исполняющий обязанности заместителя директора по ПИР и подготовке производства [PERSON] А.Б. [PERSON] [ID] ДОКУМЕНТ ПОДПИСАН ЭЛЕКТРОННОЙ ПОДПИСЬЮ Сертификат [ID] Внедрен [PERSON] [ID] Действителен с [DATE_TIME] по [DATE_TIME] N [DOCUMENT_NUMBER] от [DATE_TIME]
"""

# %%
para_text = paraphrase_document(
    source_text=source_text,
    tok=tok,
    model=para_model,
    embed_model=embed_model,
    device=device,
)
cos_score_para = cos_sim(embed_model, source_text, para_text)
bt_text = back_translate_document(
    text_orig=source_text,
    embed_model=embed_model,
    rugpt_tok=rugpt_tok,
    rugpt_model=rugpt_model,
    device=device,
)
cos_score_bt = cos_sim(embed_model, source_text, bt_text)

print("=== Source ===")
print(source_text)
print("\n=== Paraphrased ===")
print(para_text)
print(f"\nCosine similarity: {cos_score_para:.4f}")
print("\n=== Back-translated ===")
print(bt_text)
print(f"\nCosine similarity: {cos_score_bt:.4f}")
# Out:
# Sentences:   0%|          | 0/8 [00:00<?, ?it/s]
