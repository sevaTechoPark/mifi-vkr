# %% [markdown]
# # Установка зависимостей и проверка работы моделей(выполнять только один раз)

# %%
# !pip install -q transformers datasets accelerate sentencepiece huggingface_hub

# %%
import os
import sys
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
from google.colab import drive

drive.mount('/content/drive')
drive_root = '/content/drive/MyDrive/papadyk-collab/vkr'
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(HF_TOKEN)

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
repo = "sevaTechoPark/mifi-vkr"
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{repo}.git

import sys
sys.path.insert(0, "/content/mifi-vkr")
# Out:
# Cloning into 'mifi-vkr'...
# remote: Enumerating objects: 448, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 448 (delta 129), reused 189 (delta 83), pack-reused 203 (from 3)
# Receiving objects: 100% (448/448), 145.14 MiB | 17.18 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
from bert_embeddings.main import run_from_params

TRAIN_FILE = os.path.join(drive_root, "train_augmented_3.csv")
TEST_FILE = os.path.join(drive_root, "test.csv")
SAVE_DIR = os.path.join(drive_root, "saved_models", "bert_embeddings_best")

components, eval_metrics = run_from_params(
    train_file=TRAIN_FILE,
    test_file=TEST_FILE,
    output_dir=SAVE_DIR,
    num_epochs=15,
    checkpoint_every_n_epochs=8,
)
# Out:
# MLM corpus size: 3107
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# ...
# Map:   0%|          | 0/63 [00:00<?, ? examples/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie roberta.embeddings.word_embeddings.weight to lm_head.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie lm_head.bias to lm_head.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# RobertaForMaskedLM LOAD REPORT from: ai-forever/ruRoberta-large
# Key                             | Status     |  |
# ...

# %%
import os, json

best_dir = os.path.join(SAVE_DIR, "best_model")

print("best_model:", os.listdir(best_dir))

with open(os.path.join(SAVE_DIR, "metrics.json")) as f:
    print(json.dumps(json.load(f), indent=2))
# Out:
# best_model: ['pytorch_model.bin', 'mlm_meta.json', 'tokenizer_config.json', 'tokenizer.json']
# {
#   "model_name": "ai-forever/ruRoberta-large",
#   "text_col": "text",
#   "max_length": 512,
#   "mlm_probability": 0.15,
#   "train_batch_size": 4,
#   "eval_batch_size": 4,
#   "learning_rate": 2e-05,
#   "weight_decay": 0.01,
#   "num_train_epochs": 15,
#   "warmup_ratio": 0.1,
#   "logging_steps": 100,
#   "fp16": true,
#   "seed": 42,
#   "val_size": 0.02,
#   "checkpoint_every_n_epochs": 8,
#   "early_stopping_patience": 3,
#   "train_file": "/content/drive/MyDrive/papadyk-collab/vkr/train_augmented_3.csv",
#   "test_file": "/content/drive/MyDrive/papadyk-collab/vkr/test.csv",
#   "eval_loss": 0.4468410611152649,
#   "perplexity": 1.5633657999221626,
#   "best_eval_loss": 0.4154122769832611,
#   "best_epoch": 6
# }
