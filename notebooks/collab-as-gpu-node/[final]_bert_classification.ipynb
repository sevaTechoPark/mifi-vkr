# %% [markdown]
# # Установка зависимостей и проверка работы моделей(выполнять только один раз)

# %%
# !pip install -q transformers datasets accelerate sentencepiece huggingface_hub

# %%
import os
import sys
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
from google.colab import drive

drive.mount('/content/drive')
drive_root = '/content/drive/MyDrive/papadyk-collab/vkr'
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(HF_TOKEN)

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
repo = "sevaTechoPark/mifi-vkr"
# !git clone https://oauth2:{GITHUB_TOKEN}@github.com/{repo}.git

import sys
sys.path.insert(0, "/content/mifi-vkr")
# Out:
# Cloning into 'mifi-vkr'...
# remote: Enumerating objects: 448, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 448 (delta 129), reused 189 (delta 83), pack-reused 203 (from 3)
# Receiving objects: 100% (448/448), 145.14 MiB | 15.57 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
from bert_classification.main import run_from_params

TRAIN_FILE = os.path.join(drive_root, 'train_augmented_3.csv')
TEST_FILE = os.path.join(drive_root, 'test.csv')
SAVE_DIR = os.path.join(drive_root, "saved_models", "bert_classification_best")

components, eval_metrics = run_from_params(
    train_file=TRAIN_FILE,
    test_file=TEST_FILE,
    output_dir=SAVE_DIR,
)
# Out:
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Map:   0%|          | 0/2752 [00:00<?, ? examples/s]
# Map:   0%|          | 0/355 [00:00<?, ? examples/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ruRoberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: ai-forever/ruRoberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Using EarlyStoppingCallback without load_best_model_at_end=True. Once training is finished, the best model will not be loaded automatically.
#     <div>
#
#       <progress value='5160' max='5504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5160/5504 3:55:40 < 15:43, 0.36 it/s, Epoch 15/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Balanced Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>29.351943</td>
#       <td>3.269887</td>
#       <td>0.091015</td>
#       <td>0.057020</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>18.747097</td>
#       <td>2.034353</td>
#       <td>0.293310</td>
#       <td>0.269720</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>10.282250</td>
#       <td>1.856372</td>
#       <td>0.406687</td>
#       <td>0.392450</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>7.153095</td>
#       <td>1.905207</td>
#       <td>0.399373</td>
#       <td>0.398432</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.364682</td>
#       <td>1.959977</td>
#       <td>0.400701</td>
#       <td>0.401557</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.122070</td>
#       <td>2.007914</td>
#       <td>0.401435</td>
#       <td>0.411940</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.386327</td>
#       <td>2.046699</td>
#       <td>0.411161</td>
#       <td>0.409192</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.848071</td>
#       <td>2.155621</td>
#       <td>0.406027</td>
#       <td>0.419184</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.459092</td>
#       <td>2.166483</td>
#       <td>0.444138</td>
#       <td>0.442266</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.324778</td>
#       <td>2.154838</td>
#       <td>0.443373</td>
#       <td>0.442295</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.198314</td>
#       <td>2.156104</td>
#       <td>0.443607</td>
#       <td>0.438121</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.086065</td>
#       <td>2.155360</td>
#       <td>0.446686</td>
#       <td>0.451542</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.053426</td>
#       <td>2.127743</td>
#       <td>0.458465</td>
#       <td>0.450128</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.036563</td>
#       <td>2.143727</td>
#       <td>0.435183</td>
#       <td>0.447029</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.006291</td>
#       <td>2.142012</td>
#       <td>0.441360</td>
#       <td>0.448988</td>
#     </tr>
#   </tbody>
# </table><p>
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Saved checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/checkpoint_epoch_4.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Saved checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/checkpoint_epoch_8.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Saved checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/checkpoint_epoch_12.pt
# Updated best checkpoint: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
#     <div>
#
#       <progress value='355' max='355' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [355/355 00:24]
#     </div>
# FINAL METRICS
# balanced_accuracy: 0.441360
# f1_macro:          0.448988
#
# BEST METRICS
# best_epoch:         13
# balanced_accuracy:  0.446686
# f1_macro:           0.451542
# best_checkpoint:    /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/best_checkpoint.pt
# Train history saved to: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/train_history.json
# Model weights saved to: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/pytorch_model.bin
# Tokenizer saved to: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best
# Meta saved to: /content/drive/MyDrive/papadyk-collab/vkr/saved_models/bert_classification_best/training_meta.json
# Excluded from checkpoint: ['class_weights']
